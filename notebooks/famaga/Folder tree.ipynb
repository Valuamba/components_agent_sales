# %%
import os
import subprocess
import fnmatch


def list_gitignored_files():
    """
    List files and directories excluded by .gitignore in the current directory.
    """
    try:
        # Run the git command to list ignored files and directories
        result = subprocess.run(
            ["git", "ls-files", "--others", "--ignored", "--exclude-standard", "--directory"],
            check=True,
            text=True,
            capture_output=True
        )
        # Split the result by new lines to get a list of paths
        ignored_items = result.stdout.split('\n')
        # Filter out empty strings
        ignored_items = [item for item in ignored_items if item]
        return ignored_items
    except subprocess.CalledProcessError as e:
        print(f"Error running git command: {e}")
        return []


def read_gitignore_patterns(gitignore_path):
    """
    Read and parse patterns from a .gitignore file.
    """
    patterns = []
    if os.path.exists(gitignore_path):
        with open(gitignore_path, 'r') as file:
            for line in file:
                stripped_line = line.strip()
                if stripped_line and not stripped_line.startswith('#'):
                    patterns.append(stripped_line)
    return patterns


def matches_any_pattern(path, patterns):
    """
    Check if the path matches any of the .gitignore patterns.
    """
    for pattern in patterns:
        if fnmatch.fnmatch(path, pattern):
            return True
    return False


def print_tree(startpath, exclude_patterns=None, max_level=None, level=0, prefix=''):
    """
    Print the directory tree starting from 'startpath' excluding paths that match .gitignore patterns.
    """
    if exclude_patterns is None:
        exclude_patterns = []
    if max_level is not None and level > max_level:
        return
    for item in os.listdir(startpath):
        path = os.path.join(startpath, item)
        rel_path = os.path.relpath(path, startpath)
        if not matches_any_pattern(rel_path, exclude_patterns):
            if os.path.isdir(path):
                print(f"{prefix}+-- {item}")
                new_prefix = prefix + "|   "
                print_tree(path, exclude_patterns, max_level, level + 1, new_prefix)
            elif os.path.isfile(path):
                print(f"{prefix}+-- {item}")

if __name__ == "__main__":
    root_dir = r'C:\Users\MGroup\components_agent_sales'
    gitignore_path = os.path.join(root_dir, '.gitignore')
    exclude_patterns = read_gitignore_patterns(gitignore_path) + ['.git', 'node_modules', 'venv', 
        '__pycache__', 'prompt_client', 'sales-copilot-frontend', '.ipynb_checkpoints',
        'alembic']
    max_depth = 3

    print_tree(root_dir, exclude_patterns, max_depth)
# Out:
# +-- .dockerignore
# +-- .gitignore
# +-- .pre-commit-config.yaml
# +-- .python-version
# +-- app
# |   +-- adr
# |   |   +-- db.txt
# |   +-- agents
# |   |   +-- base.py
# |   |   +-- classify_intents
# |   |   |   +-- agent.py
# |   |   |   +-- prompts.py
# |   |   +-- classify_parts
# |   |   |   +-- agent.py
# |   |   |   +-- prompts.py
# |   |   +-- __init__.py
# |   +-- alembic.ini
# |   +-- api
# |   |   +-- completion.py
# |   |   +-- router.py
# |   |   +-- v1
# |   |   |   +-- parts.py
# |   |   |   +-- __init__.py
# |   |   +-- __init__.py
# |   +-- configs
# |   |   +-- config.py
# |   |   +-- logger.py
# |   |   +-- __init__.py
# |   +-- database.py
# |   +-- dependencies.py
# |   +-- dependencies_v2.py
# |   +-- logs
# |   +-- main.py
# |   +-- models
# |   |   +-- base.py
# |   |   +-- deal.py
# |   |   +-- deal_info.py
# |   |   +-- embedding.py
# |   |   +-- parts.py
# |   |   +-- __init__.py
# |   +-- repositories
# |   |   +-- base.py
# |   |   +-- completion_history.py
# |   |   +-- deal_repository.py
# |   |   +-- detail_info_repository.py
# |   |   +-- embedding_repository.py
# |   |   +-- intents.py
# |   |   +-- message.py
# |   |   +-- part_inquiry.py
# |   |   +-- task.py
# |   |   +-- __init__.py
# |   +-- schemas
# |   |   +-- completion.py
# |   |   +-- v1
# |   |   |   +-- classify_part.py
# |   |   |   +-- email_parser.py
# |   |   |   +-- intent.py
# |   |   |   +-- part.py
# |   +-- services
# |   |   +-- classify_email_agent.py
# |   |   +-- google_search.py
# |   |   +-- logger_service.py
# |   |   +-- openai_client.py
# |   |   +-- __init__.py
# |   +-- utility.py
# |   +-- __init__.py
# +-- arch
# |   +-- arch
# |   +-- arch.md
# |   +-- flow-overview.puml
# +-- assets
# |   +-- 7df4dbdc-eb62-4d53-bc27-d334bfcb2335.pdf
# |   +-- brands.csv
# |   +-- email.eml
# |   +-- ic-20-ic-50-actuators_brochure.pdf
# |   +-- ic-20-ic-50-actuators_brochure.pkl
# |   +-- ic-20-ic-50-datasheet.pdf
# |   +-- manufacturer_detail.txt
# |   +-- pdf2htmlEX-0.18.8.rc1-master-20200630-Ubuntu-bionic-x86_64.deb
# |   +-- price.html
# |   +-- quarterly-nvidia.pdf
# |   +-- quarterly-nvidia.pkl
# +-- create_dump.py
# +-- debug_init_agent.py
# +-- deploy
# |   +-- prod
# |   |   +-- docker-compose.yml
# |   |   +-- pg.Dockerfile
# +-- docker
# |   +-- Dockerfile
# +-- figma
# |   +-- sales.fig
# +-- Find prices and technical data of manufacturer detail.ipynb
# +-- gather_detail_info.ipynb
# +-- imap_connection.ipynb
# +-- init.sql
# +-- langchain_forest.ipynb
# +-- langchain_scraper-Copy1.ipynb
# +-- langchain_scraper_react.ipynb
# +-- learn.md
# +-- load_data_postgres.ipynb
# +-- migrations
# |   +-- init_dbs.sql
# +-- notebooks
# |   +-- .cache
# |   |   +-- 41
# |   |   |   +-- cache.db
# |   +-- 112849
# |   +-- adr
# |   |   +-- classification_agent.ipynb
# |   |   +-- prompts.py
# |   |   +-- prompt_versions.db
# |   |   +-- Untitled.ipynb
# |   +-- Agents Copilot.ipynb
# |   +-- assets
# |   |   +-- deals.json
# |   |   +-- payment.json
# |   +-- Autogen Test.ipynb
# |   +-- Communicate with docs.ipynb
# |   +-- Context Conversation.ipynb
# |   +-- Crawl Async Arch.ipynb
# |   +-- emails.txt
# |   +-- embedded_tables_unstructured_pack
# |   |   +-- base.py
# |   |   +-- requirements.txt
# |   +-- example.jpg
# |   +-- famaga
# |   |   +-- agents
# |   |   |   +-- discount_agent
# |   |   |   +-- intent_classifier
# |   |   |   +-- openai_client.py
# |   |   |   +-- senior_sales
# |   |   |   +-- statics.py
# |   |   |   +-- utils.py
# |   |   +-- assets
# |   |   +-- classification_agent.ipynb
# |   |   +-- Classify Intents.ipynb
# |   |   +-- deals_analysis.ipynb
# |   |   +-- deals_html
# |   |   |   +-- 391303.html
# |   |   |   +-- 413460.html
# |   |   |   +-- 426089.html
# |   |   |   +-- 429284.html
# |   |   |   +-- 429918.html
# |   |   |   +-- 432086.html
# |   |   |   +-- 434036.html
# |   |   +-- eml_parser.ipynb
# |   |   +-- Extract messages from email.ipynb
# |   |   +-- Extract Messaging History.ipynb
# |   |   +-- extracted_deals_messaging.db
# |   |   +-- extract_blockquotes.py
# |   |   +-- extract_messaging_history.py
# |   |   +-- feedback.txt
# |   |   +-- Folder tree.ipynb
# |   |   +-- htmls
# |   |   |   +-- content.html
# |   |   +-- migrate_purchase_history.ipynb
# |   |   +-- openai_client.py
# |   |   +-- Preprocess messaging history with client.ipynb
# |   |   +-- prompts
# |   |   |   +-- discounts
# |   |   |   +-- interesting_results.py
# |   |   |   +-- __init__.py
# |   |   +-- prompt_versions.db
# |   |   +-- prompt_versions_1.db
# |   |   +-- Scenario 1.ipynb
# |   |   +-- scenarios.csv
# |   |   +-- Sessions and UnitOfWork alchemy.ipynb
# |   |   +-- test_discount.ipynb
# |   |   +-- test_sql_alchemy.ipynb
# |   |   +-- Untitled.ipynb
# |   |   +-- Untitled1.ipynb
# |   |   +-- utils.py
# |   |   +-- your_database_name.db
# |   +-- Find prices and technical data of manufacturer detail.ipynb
# |   +-- gather_detail_info.ipynb
# |   +-- guide_react.ipynb
# |   +-- langchain_forest.ipynb
# |   +-- langchain_scraper-Copy1.ipynb
# |   +-- langchain_scraper_react.ipynb
# |   +-- learn_chroma.ipynb
# |   +-- learn_initilaize_agent.ipynb
# |   +-- load_data_postgres.ipynb
# |   +-- mention the directory where you want the files to be download
# |   |   +-- Proforma_453757.pdf
# |   +-- myproject
# |   |   +-- myproject
# |   |   |   +-- items.py
# |   |   |   +-- middlewares.py
# |   |   |   +-- pipelines.py
# |   |   |   +-- settings.py
# |   |   |   +-- spiders
# |   |   |   +-- __init__.py
# |   |   +-- scrapy.cfg
# |   +-- OAI_CONFIG_LIST.json
# |   +-- Parse correct brand name.ipynb
# |   +-- Perplexity Search Test.ipynb
# |   +-- pg_vector_embeddings.ipynb
# |   +-- prompts
# |   |   +-- discounts
# |   |   |   +-- block_schema.py
# |   +-- S3toWBBasket.ipynb
# |   +-- scrapy_test.py
# |   +-- semantic_search.ipynb
# |   +-- test.ipynb
# |   +-- Tim Connors solution for parsing.ipynb
# |   +-- unstructured_data_llama.ipynb
# |   +-- Untitled.ipynb
# |   +-- YouTrack
# |   |   +-- add_traicing.ipynb
# |   |   +-- alljobswb.json
# |   |   +-- hr
# |   |   +-- hr.json
# |   |   +-- hr_portal_audit.csv
# |   |   +-- hr_portal_reps.ipynb
# |   |   +-- statics.py
# |   |   +-- Untitled.ipynb
# |   |   +-- vulns.csv
# |   |   +-- YouTrack.ipynb
# |   |   +-- yt.ini
# |   +-- __init__.py
# +-- out
# |   +-- arch
# |   |   +-- flow-overview
# +-- package-lock.json
# +-- package.json
# +-- Perplexity Search Test.ipynb
# +-- pg_vector_embeddings.ipynb
# +-- requirements.txt
# +-- search_details_script.py
# +-- semantic_search.ipynb
# +-- socket-producer.py
# +-- test.ipynb
# +-- test_discount.ipynb
# +-- Tim Connors solution for parsing.ipynb
# +-- unstructured_data_llama.ipynb
# +-- Untitled.ipynb

# %%
list_gitignored_files()
# Out:
# ['.idea/',
#  '.ipynb_checkpoints/',
#  '.ipynb_checkpoints/Classify Intents-checkpoint.ipynb',
#  '.ipynb_checkpoints/Extract Messaging History-checkpoint.ipynb',
#  '.ipynb_checkpoints/Extract messages from email-checkpoint.ipynb',
#  '.ipynb_checkpoints/Folder tree-checkpoint.ipynb',
#  '.ipynb_checkpoints/Preprocess messaging history with client-checkpoint.ipynb',
#  '.ipynb_checkpoints/Scenario 1-checkpoint.ipynb',
#  '.ipynb_checkpoints/Sessions and UnitOfWork alchemy-checkpoint.ipynb',
#  '.ipynb_checkpoints/Untitled-checkpoint.ipynb',
#  '.ipynb_checkpoints/Untitled1-checkpoint.ipynb',
#  '.ipynb_checkpoints/classification_agent-checkpoint.ipynb',
#  '.ipynb_checkpoints/deals_analysis-checkpoint.ipynb',
#  '.ipynb_checkpoints/eml_parser-checkpoint.ipynb',
#  '.ipynb_checkpoints/extract_blockquotes-checkpoint.py',
#  '.ipynb_checkpoints/feedback-checkpoint.txt',
#  '.ipynb_checkpoints/migrate_purchase_history-checkpoint.ipynb',
#  '.ipynb_checkpoints/openai_client-checkpoint.py',
#  '.ipynb_checkpoints/scenarios-checkpoint.csv',
#  '.ipynb_checkpoints/test_discount-checkpoint.ipynb',
#  '.ipynb_checkpoints/test_sql_alchemy-checkpoint.ipynb',
#  '.ipynb_checkpoints/utils-checkpoint.py',
#  '__pycache__/',
#  '__pycache__/openai_client.cpython-312.pyc',
#  '__pycache__/utils.cpython-312.pyc',
#  'agents/__pycache__/',
#  'agents/__pycache__/openai_client.cpython-312.pyc',
#  'agents/__pycache__/statics.cpython-312.pyc',
#  'agents/__pycache__/utils.cpython-312.pyc',
#  'agents/discount_agent/__pycache__/',
#  'agents/discount_agent/__pycache__/prompt.cpython-312.pyc',
#  'agents/intent_classifier/__pycache__/',
#  'agents/intent_classifier/__pycache__/agent.cpython-312.pyc',
#  'agents/intent_classifier/__pycache__/base.cpython-312.pyc',
#  'agents/intent_classifier/__pycache__/classify_intents.cpython-312.pyc',
#  'agents/intent_classifier/__pycache__/classify_intents_prompt.cpython-312.pyc',
#  'agents/senior_sales/__pycache__/',
#  'agents/senior_sales/__pycache__/agent.cpython-312.pyc',
#  'deals_html/.ipynb_checkpoints/',
#  'deals_html/.ipynb_checkpoints/391303-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/413460-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/426089-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/429284-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/429918-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/432086-checkpoint.html',
#  'deals_html/.ipynb_checkpoints/434036-checkpoint.html',
#  'prompts/.ipynb_checkpoints/',
#  'prompts/.ipynb_checkpoints/interesting_results-checkpoint.py',
#  'prompts/__pycache__/',
#  'prompts/__pycache__/__init__.cpython-312.pyc',
#  'prompts/discounts/.ipynb_checkpoints/',
#  'prompts/discounts/.ipynb_checkpoints/block_schema_v2-checkpoint.py',
#  'prompts/discounts/__pycache__/',
#  'prompts/discounts/__pycache__/__init__.cpython-312.pyc',
#  'prompts/discounts/__pycache__/block_schema.cpython-312.pyc',
#  'prompts/discounts/__pycache__/block_schema_v2.cpython-312.pyc']
