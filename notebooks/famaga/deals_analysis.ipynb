# %%
import pandas as pd

df = pd.read_json(r'C:\Users\MGroup\Documents\products.json')

# %%
# Calculate the percentage change in price and quantity demanded for each item
df['price_sell'] = pd.to_numeric(df['price_sell'])
df['price_change'] = df.groupby('articul')['price_sell'].pct_change()
df['quantity_change'] = df.groupby('articul')['amount'].pct_change()

# Calculate Price Elasticity of Demand
df['PED'] = df['quantity_change'] / df['price_change']

# Display the results
df.dropna(inplace=True)  # Remove rows with NaN values (first rows for each articul where pct_change cannot be calculated)
df
# Out:
# C:\Users\MGroup\AppData\Local\Temp\ipykernel_8240\618521451.py:3: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['price_change'] = df.groupby('articul')['price_sell'].pct_change()
#                          articul      id              brand_title  brand_id  \
# 41                  EKCA2 KUC/ZQ  374410                  Waircom    7181.0
# 97                     92423A149  374547            McMaster-Carr   13639.0
# 98                     92423A149  374547            McMaster-Carr   13639.0
# 99                     92423A149  374547            McMaster-Carr   13639.0
# 104                         IQ96  374593          CEWE INSTRUMENT    4459.0
# ...                          ...     ...                      ...       ...
# ...
